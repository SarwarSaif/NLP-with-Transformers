# %% [markdown]
# # The three eras of AI:
# 1. **Symbolic** (1950-1980)
#   - Pros: Rule-based, easily interpretable.
#   - Cons: Creating rule for every scenario is not possible, no support for context utilization.
# 2. **Statistical** (1980-2010)
#   - Pros: Generalized, less domain knowledge is needed.
#   - Cons: Limited information as the models are generalized.
# 3. **Neural** (2010~)
#   - Pros: Adaptable, accurate and ease of use.
#   - Cons: Still brittle, difficult to interpret or in some cases uncertain.

# %% [markdown]
# # Word Vector
# At the beginning the words in a sentence was used to get represented as a One-hot-encoding.
# Then Mokoliv came with 'Word2Vec' which was a better and automatic way of doing the conversion in a way that allowed us to represent both similarity and relationship between the words through the use of word vectors.
# Word vectors are simply vectors of numbers that represent the meaning of a word. In simpler terms, a word vector is a row of real-valued numbers (as opposed to dummy numbers) where each point captures a dimension of the word's meaning and where semantically similar words have similar vectors.
# ![linear-relationships.png](data:image/png;base64,...)

# %% [markdown]
# # Recurrent Neural Networks (RNN)
# Recurrent Neural Network(RNN) are a type of Neural Network where the output from previous step are fed as input to the current step. In traditional neural networks, all the inputs and outputs are independent of each other, but in cases like when it is required to predict the next word of a sentence, the previous words are required and hence there is a need to remember the previous words. Thus RNN came into existence, which solved this issue with the help of a Hidden Layer. The main and most important feature of RNN is Hidden state or memory, which remembers some information about a sequence.
# But, RNN has Vanishing Gradient Problem and thus unable to preserve context of the long sentences.
# - **Pros:**
#   1. An RNN remembers each and every information through time. It is useful in time series prediction only because of the feature to remember previous inputs as well. This is called Long Short Term Memory.
#   2. Recurrent neural network are even used with convolutional layers to extend the effective pixel neighborhood.
# - **Cons:**
#   1. Gradient vanishing and exploding problems.
#   2. Training an RNN is a very difficult task.
#   3. It cannot process very long sequences if using tanh or relu as an activation function.
#
# Gradient vanishing and exploding problems.
# Training an RNN is a very difficult task.
# It cannot process very long sequences if using tanh or relu as an activation function.
# ![rnn1.PNG](data:image/png;base64,...)

# %% [markdown]
# # Long Short Term Memory (LSTM)
# Long Short Term Memory networks – usually just called “LSTMs” – are a special kind of RNN, capable of learning long-term dependencies. They were introduced by Hochreiter & Schmidhuber (1997), and were refined and popularized by many people. They work tremendously well on a large variety of problems, and are now widely used.
#
# LSTMs are explicitly designed to avoid the long-term dependency problem (Vanishing Gradient Problem in RNN). Remembering information for long periods of time is practically their default behavior, not something they struggle to learn!
# ![lstm1.PNG](data:image/png;base64,...)

# %% [markdown]
# # Encoder-Decoder Sequence to Sequence Modeling
# [Introduced for the first time in 2014 by Google](https://arxiv.org/pdf/1409.3215.pdf), a sequence to sequence model aims to map a fixed-length input with a fixed-length output where the length of the input and output may differ.
# For example, translating “What are you doing today?” from English to Chinese has input of 5 words and output of 7 symbols (今天你在做什麼？). Clearly, we can’t use a regular LSTM network to map each word from the English sentence to the Chinese sentence.
# This is why the sequence to sequence model is used to address problems like that one.
# The model consists of 3 parts: encoder, intermediate (encoder) vector and decoder.
# - **Encoder**
# A stack of several recurrent units (LSTM or GRU cells for better performance) where each accepts a single element of the input sequence, collects information for that element and propagates it forward.
# - **Decoder**
# A stack of several recurrent units where each predicts an output y_t at a time step t.
# Each recurrent unit accepts a hidden state from the previous unit and produces and output as well as its own hidden state.
# ![1_1JcHGUU7rFgtXC_mydUA_Q.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Encoder Decoder Attention
# Attention is proposed as a solution to the limitation of the Encoder-Decoder model encoding the input sequence to one fixed length vector from which to decode each output time step. This issue is believed to be more of a problem when decoding long sequences.
# Encode-Decoder Seq2Seq modeling had a Information bottleneck due to their single connection between Encoder and Decoder layer.
#
# **Attention is proposed as a method to both align and translate.**
#
# Alignment is the problem in machine translation that identifies which parts of the input sequence are relevant to which word in the output, whereas translation is the process of using the relevant information to select the appropriate output.
# In Encoder-Decoder Attention mechanism, we can determine how much a word in Encoder is Relavent to a word in the Decoder and thus can create an Attention or Allignment matrix. In this way, we can find the best Relavent Decoded Word for each Encoded Words.
#
# ![encoderdecoder-attention.PNG](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Solo Attention or Transformer
# The journey of using only the Attention mechanism after the publish of the paper in 2017, named [Attention is all you need](https://arxiv.org/pdf/1706.03762.pdf).
# This paper introduced the concept of that we don't need to use this complex convolution of Recurrent Networks alongside Attention. In fact Attention is all we need.
# So to use the Attention to work independently, some changes were made. Primarily those are:
# - Self-attention
# - Multi-head attention
# - Positional encoding
#
# And this all Created the First form of **Transformer**
#
# ![attentionisallyouneed.png](data:image/png;base64,...)

# %% [markdown]
# ## Self Attention
# Due to Self-attention mechanism, we are now able to encode the allignment between different parts of the **same input sequence**, which allows us to encode relationships between all of the words and the input data, which essentially produces much more meaningful numerical word vectors.
#
# ![self-attention-1.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Multi-head Attention
# In the Transformer, the Attention module repeats its computations multiple times in parallel. Each of these is called an Attention Head. The Attention module splits its Query, Key, and Value parameters N-ways and passes each split independently through a separate Head. All of these similar Attention calculations are then combined together to produce a final Attention score. This is called Multi-head attention and gives the Transformer greater power to encode multiple relationships and nuances for each word.
# > It's the concept of having multiple heads in parallel.
#
# > It's the most important part of the paper "Attention is all you need". As without the Multi-head Attention the algorithm performs poorly from it's predecessors.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Positional Encoding
# A Input to Transformer is not sequential like that in Recurrent Neural Networks.
